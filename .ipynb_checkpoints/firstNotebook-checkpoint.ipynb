# %%
# %pylab notebook
import cv2
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
img = cv2.imread('sky.jpg', 1)
row, col, channel = img.shape
cv2.line(img, (0,0), (col, row), (255, 0, 0), 5)
cv2.rectangle(img, (50, 50), (600, 600), (0, 0, 255),  5)
imshow(img)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
face_cascade = cv2.CascadeClassifier("/Users/macbook/anaconda3/pkgs/opencv-3.3.1-py36hb620dcb_1/share/OpenCV/haarcascades/haarcascade_frontalface_default.xml")
eye_cascade = cv2.CascadeClassifier("/Users/macbook/anaconda3/pkgs/opencv-3.3.1-py36hb620dcb_1/share/OpenCV/haarcascades/haarcascade_eye.xml")

# %%
cap = cv2.VideoCapture(0)

while(True):
    # Capture frame-by-frame
    ret, img = cap.read()

    # Our operations on the frame come here
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        for (ex,ey,ew,eh) in eyes:
            cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
            
    # Display the resulting frame
    cv2.imshow('frame',img)
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# -1
